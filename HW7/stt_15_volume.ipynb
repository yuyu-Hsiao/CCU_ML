# %% [markdown]
# # LSTM_Stock_Prediction
#
#
# 給定 2010 ~ 2016 紐約股市的資料：
#
# 1. `stt.csv`：State Street Corp (STT) 的資料。
# 2. `all.csv`：STT 以外其他公司的資料。
#
# csv 中每一行有以下欄位：
#
# 1. `date`：日期
# 2. `symbol`: 公司
# 3. `open`：開盤價
# 4. `close`：收盤價
# 5. `low`：低點
# 6. `hight`：高點
# 7. `volume`：交易量
#
# 作業如下：
#
# 1. 使用 STT 前 15 天的資料來預測第 16 天的交易量(30%)
# 2. 使用所有跟 STT 同領域的公司前 15 天的資料來預測 STT 第 16 天的收盤價(30%)
# 3. 使用整個股市的資料前 30 天的資料來預測第 31 天的開盤價(40%)
#
#
# ### 以下範例程式使用STT過去15天的`open`、`close`、`low`和`volume`（without  `high`），來預測STT第16天的最高價（`high`）。

# %% [markdown]
# ## Task:
#
# 1. Use a RNN/LSTM.
# 2. Plot the loss curve.
# 3. Report the $MSE$ between your predictions and groundtruths. (both train and valid set)
#
# $$
# MSE = \frac{1}{N} \sum_1^N (p_i - q_i)^2
# $$
# 4. Plot the prediction vs groundtruth. (both train and valid set)
#
#
# where $N$ is number of days and $p_i, q_i$ are the prediction and groudtruth on day $i$ respectively.

# %% [markdown]
# ## Download Data and Import Libraries

# %%
from pathlib import Path
from torchvision.datasets.utils import download_file_from_google_drive

csv_path_stt = Path('./stt.csv')
csv_path_all = Path('./all.csv')

if not csv_path_stt.exists():
    download_file_from_google_drive('1zY26f3Ie5c7Vt9R0wHRz9hGldOsizV4b', '.', csv_path_stt)
if not csv_path_all.exists():
    download_file_from_google_drive('1KtyafQZRtx3FOWpFEe-keoeiVTb2y7Fu', '.', csv_path_all)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm

import torch
from torch import nn
from torch.nn import functional as F
from torch.utils.data import Dataset, DataLoader, Sampler

from sklearn.preprocessing import StandardScaler

# %%
df_stt = pd.read_csv(csv_path_stt)      # a DataFrame object
df_stt = df_stt.sort_values(by='date')  # csv are not guarenteed to be ordered by date
df_stt.head(10)
# Out:
#          date symbol       open      close        low       high     volume
# 0  2010-01-04    STT  43.810001  44.459999  43.549999  44.779999  3440300.0
# 1  2010-01-05    STT  44.520000  44.549999  44.020000  45.000000  3992500.0
# 2  2010-01-06    STT  44.400002  43.810001  43.650002  44.669998  4062100.0
# 3  2010-01-07    STT  44.349998  44.599998  43.980000  44.860001  5273100.0
# 4  2010-01-08    STT  44.759998  45.509998  44.389999  45.880001  6038000.0
# 5  2010-01-11    STT  45.889999  44.360001  44.209999  46.099998  4260000.0
# 6  2010-01-12    STT  43.910000  44.200001  43.910000  44.849998  3432600.0
# 7  2010-01-13    STT  44.500000  44.610001  43.650002  44.770000  2741000.0
# 8  2010-01-14    STT  44.330002  43.790001  43.189999  44.419998  4268500.0
# 9  2010-01-15    STT  43.520000  42.669998  42.520000  44.099998  6887100.0

# %% [markdown]
# ### Train/Valid Split and Feature Normalization
#
# We split first 85% of the entries to be training data, and last 15% to be validation data.
# The pivot date is 2015-12-15, i.e., entries after 2015-12-15 (included) is valid data.
#
#
# Note that scale of the features (`open`, `close`, `low`, `high`, `volume`) are different to each other. In practice, we normalize each features to better train our model. If we do so, the model will suffer gradient vanishment/exploding.
#
# To normalize data, common techniques are:
#
# 1. Standard Scaler: $x_{new} = (x - mean) / std$
# 2. Minmax Scaler: $x_{new} = (x - x_{min}) / (x_{max} - x_{min})$
#
# Both are implemented in `sklearn`. In this code, we use the first one.
#
# **Be careful that when normalizing data, we can use only training data to compute the statistics. Using validation/testing data is not allowed.**
#
#
# In some cases, we need to obtain original values from normalized features, we can do it using the standard scaler `std` used for normalization.
#
# ```python
# raw_open = normalize_open* std.scale_[0] + std.mean_[0]
# raw_close = normalized_close * std.scale_[1] + std.mean_[1]
# raw_low = normalized_low * std.scale_[2] + std.mean_[2]
# raw_high = normalized_low * std.scale_[3] + std.mean_[3]
# raw_volume = normalized_low * std.scale_[4] + std.mean_[4]
# ```

# %%
pivot = round(0.85 * len(df_stt))
print('pivot:', df_stt.loc[pivot, 'date'])

df_train = df_stt[:pivot].copy()    # DataFrame
df_valid = df_stt[pivot:].copy()    # DataFrame

FEATURES = ['open', 'close', 'low', 'high', 'volume']
std = StandardScaler().fit(df_train[FEATURES])
df_train[FEATURES] = std.transform(df_train[FEATURES])
df_valid[FEATURES] = std.transform(df_valid[FEATURES])

df_train.head(10)
# Out:
# pivot: 2015-12-15
#          date symbol      open     close       low      high    volume
# 0  2010-01-04    STT -0.810652 -0.767338 -0.794788 -0.778688 -0.038990
# 1  2010-01-05    STT -0.762428 -0.761233 -0.762792 -0.763806  0.254822
# 2  2010-01-06    STT -0.770578 -0.811429 -0.787981 -0.786130  0.291854
# 3  2010-01-07    STT -0.773975 -0.757841 -0.765515 -0.773276  0.936197
# 4  2010-01-08    STT -0.746127 -0.696113 -0.737603 -0.704275  1.343181
# 5  2010-01-11    STT -0.669376 -0.774121 -0.749857 -0.689393  0.397152
# 6  2010-01-12    STT -0.803860 -0.784974 -0.770281 -0.773953 -0.043087
# 7  2010-01-13    STT -0.763786 -0.757163 -0.787981 -0.779365 -0.411070
# 8  2010-01-14    STT -0.775333 -0.812786 -0.819296 -0.803042  0.401674
# 9  2010-01-15    STT -0.830349 -0.888759 -0.864908 -0.824689  1.794966

# %% [markdown]
# # Dataset
#
# To predict the stock on day 16 based on day 1 ~ day 15 features, we expect each sample contains:
#
# 1. `feature`: the features of day 1 ~ 15. Each day has 4 features, thus the shape is `[15, 4]`.
# 2. `target`: the target we are predicting. In this case, it's the `high` of day 16, thus `target` is a shaped `[1]`.
#
# Therefore we are performing a *sliding window*-like operation on the given dataframe.

# %%
class CompanyStockData(Dataset):
    def __init__(self, dataframe, window=10):
        super().__init__()
        self.df = dataframe
        self.window = window

    def __len__(self):
        return len(self.df) - self.window

    def __getitem__(self, idx):
        window_s = idx
        window_t = idx + self.window
        feature = self.df.iloc[window_s:window_t - 1]                            # Retrieve entries [window_s, window_t - 1], DataFrame
        feature = feature[['open', 'close', 'low', 'high']].values                    # Retrieve the wanted features. `.values` make it ndarray
        feature = torch.from_numpy(feature).float()                               # Converty ndarray to tensor
        target = self.df.iloc[window_t - 1]                                 # The entry on the next day
        target = target['volume'].item()                                      # Make it python scalar
        target = torch.tensor([target]).float()                               # Make it tensor
        return feature, target


WINDOW = 16
train_set = CompanyStockData(df_train, window=WINDOW)
valid_set = CompanyStockData(df_valid, window=WINDOW)
print('#train:', len(train_set))
print('#valid:', len(valid_set))

feature, target = valid_set[100]
print(feature)
print(target)
# Out:
# #train: 1482
# #valid: 248
# tensor([[0.2965, 0.3621, 0.3264, 0.3314],
#         [0.3501, 0.3126, 0.3482, 0.3355],
#         [0.3386, 0.2888, 0.2985, 0.3314],
#         [0.2822, 0.2346, 0.2659, 0.3003],
#         [0.2204, 0.2671, 0.2563, 0.2590],
#         [0.2571, 0.2658, 0.2502, 0.2678],
#         [0.2679, 0.3885, 0.2795, 0.3612],
#         [0.3589, 0.3356, 0.3312, 0.3598],
#         [0.3685, 0.3838, 0.3870, 0.3680],
#         [0.3780, 0.3716, 0.3795, 0.3639],
#         [0.4065, 0.4598, 0.4320, 0.4336],
#         [0.4894, 0.5364, 0.5109, 0.5283],
#         [0.5308, 0.4815, 0.5157, 0.5161],
#         [0.5070, 0.5127, 0.5218, 0.4796],
#         [0.5362, 0.4944, 0.5109, 0.4972]])
# tensor([-0.8871])

# %% [markdown]
# # Model
#
# We implements following model:

# %%
class LSTM(nn.Module):
    def __init__(self, input_size=4, hidden_size=32, num_layers=1, num_classes=1):
        super().__init__()
        self.lstm = nn.LSTM(
            input_size=input_size, hidden_size=hidden_size, num_layers=num_layers, batch_first=True
        )
        self.regressor = nn.Linear(hidden_size, num_classes)

    def forward(self, x):
        x, (h, c) = self.lstm(x)
        x = self.regressor(x[:, -1])        # We only takes last timestamps output of lstm
        return x

train_loader = DataLoader(
    train_set,
    shuffle=True,
    batch_size=8,
    num_workers=4,
)
valid_loader = DataLoader(
    valid_set,
    shuffle=False,
    batch_size=8,
    num_workers=4,
)

feature_b, target_b = next(iter(valid_loader))
print(feature_b.shape)  # [N, 15, 4]
print(target_b.shape)   # [N, 1]

model = LSTM(input_size=4, hidden_size=32, num_classes=1)
output_b = model(feature_b)
print(output_b.shape)   # [N, 1]
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:558: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# torch.Size([8, 15, 4])
# torch.Size([8, 1])
# torch.Size([8, 1])

# %% [markdown]
# Some other RNN model you can try:

# %%
class BiLSTM(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers, num_classes):
        super(BiLSTM, self).__init__()

        self.lstm = nn.LSTM(
            input_size, hidden_size, num_layers, batch_first=True, bidirectional=True
        )
        self.fc = nn.Linear(hidden_size * 2, num_classes)

    def forward(self, x):
        x, _ = self.lstm(x)
        x = self.fc(x[:, -1, :])
        return x


class GRU(nn.Module):
    def __init__(self, input_size, hidden_size=1, num_layers=1, num_classes=1):
        super().__init__()

        self.gru = nn.GRU(input_size, hidden_size, num_layers, batch_first=True)
        self.fc = nn.Linear(hidden_size, num_classes)

    def forward(self, x):
        x, _ = self.gru(x)
        x = self.fc(x[:, -1, :])
        return x

# %% [markdown]
# # Training
#
# Train the model in standard way and record losses every epoch.

# %%
device = 'cuda'
model = LSTM(input_size=4, hidden_size=32, num_layers=1, num_classes=1).to(device)
criterion = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)

history = {
    'train_loss': [],
    'valid_loss': [],
}

for epoch in tqdm(range(50)):
    # Train
    losses = []
    model.train()
    for feature_b, target_b in iter(train_loader):
        feature_b = feature_b.to(device)
        target_b = target_b.to(device)

        optimizer.zero_grad()
        predict_b = model(feature_b)
        loss = criterion(predict_b, target_b)
        loss.backward()
        optimizer.step()

        losses.append(loss.item())
    train_loss = sum(losses) / len(losses)

    # Valid
    losses = []
    model.eval()
    for feature_b, target_b in iter(valid_loader):
        feature_b = feature_b.to(device)
        target_b = target_b.to(device)
        predict_b = model(feature_b)
        loss = criterion(predict_b, target_b)
        losses.append(loss.item())
    valid_loss = sum(losses) / len(losses)

    # Logging
    history['train_loss'].append(train_loss)
    history['valid_loss'].append(valid_loss)
    print('Epoch {:03d}: {:.6f}, {:.6f}'.format(
        epoch, train_loss, valid_loss
    ))
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
# Epoch 000: 0.733565, 0.319066
# Epoch 001: 0.700496, 0.297546
# Epoch 002: 0.703942, 0.298541
# Epoch 003: 0.688933, 0.295853
# Epoch 004: 0.693326, 0.311229
# Epoch 005: 0.692487, 0.294928
# Epoch 006: 0.686715, 0.297883
# Epoch 007: 0.684518, 0.309808
# Epoch 008: 0.676532, 0.287760
# Epoch 009: 0.681813, 0.297256
# Epoch 010: 0.677890, 0.287703
# Epoch 011: 0.677586, 0.314129
# Epoch 012: 0.676087, 0.304165
# Epoch 013: 0.672712, 0.305899
# Epoch 014: 0.673754, 0.309297
# Epoch 015: 0.672024, 0.314615
# Epoch 016: 0.667616, 0.309595
# Epoch 017: 0.667755, 0.304654
# Epoch 018: 0.665739, 0.312232
# Epoch 019: 0.662047, 0.307461
# Epoch 020: 0.655845, 0.308606
# Epoch 021: 0.665435, 0.324907
# Epoch 022: 0.654308, 0.318501
# Epoch 023: 0.647135, 0.384687
# Epoch 024: 0.644954, 0.336307
# Epoch 025: 0.635555, 0.345434
# Epoch 026: 0.672337, 0.405164
# Epoch 027: 0.636848, 0.433074
# Epoch 028: 0.642130, 0.371790
# Epoch 029: 0.632337, 0.368196
# Epoch 030: 0.641548, 0.431603
# Epoch 031: 0.645832, 0.385998
# Epoch 032: 0.637496, 0.394786
# Epoch 033: 0.634759, 0.395620
# Epoch 034: 0.622789, 0.464061
# Epoch 035: 0.624990, 0.416439
# Epoch 036: 0.625321, 0.428819
# Epoch 037: 0.620460, 0.421709
# Epoch 038: 0.635111, 0.403819
# Epoch 039: 0.624830, 0.347726
# Epoch 040: 0.620040, 0.415013
# Epoch 041: 0.616493, 0.381526
# Epoch 042: 0.615722, 0.386591
# Epoch 043: 0.614950, 0.513513
# Epoch 044: 0.611671, 0.441632
# Epoch 045: 0.614654, 0.390982
# Epoch 046: 0.615251, 0.431392
# Epoch 047: 0.615679, 0.379190
# Epoch 048: 0.611413, 0.417058
# Epoch 049: 0.605741, 0.445012

# %%
fig, ax = plt.subplots()
ax.plot(history['train_loss'], label='Train')
ax.plot(history['valid_loss'], label='Valid')
ax.set_title('Loss')
ax.legend()
plt.show()

# %% [markdown]
# ## Evaluation

# %%
@torch.no_grad()
def evaluate(dataset):
    model.eval()
    preds = []
    trues = []
    loader = DataLoader(dataset, batch_size=32, shuffle=False, num_workers=4)
    for feature_b, target_b in tqdm(iter(loader)):
        predict_b = model(feature_b.to(device)).to('cpu')
        preds.extend(predict_b)
        trues.extend(target_b)
    preds = torch.stack(preds).numpy() # [N]
    trues = torch.stack(trues).numpy() # [N]
    return preds, trues


preds, trues = evaluate(train_set)
preds = preds * std.scale_[4] + std.mean_[4]
trues = trues * std.scale_[4] + std.mean_[4]
error = ((preds - trues) ** 2).mean()
fig, ax = plt.subplots()
ax.plot(trues, label='True')
ax.plot(preds, label='Pred')
ax.set_title(f'Train Error={error:.3f}')
ax.legend()
plt.show()

preds, trues = evaluate(valid_set)
preds = preds * std.scale_[4] + std.mean_[4]
trues = trues * std.scale_[4] + std.mean_[4]
error = ((preds - trues) ** 2).mean()
fig, ax = plt.subplots()
ax.plot(trues, label='True')
ax.plot(preds, label='Pred')
ax.set_title(f'Valid Error={error:.3f}')
ax.legend()
plt.show()
# Out:
#   0%|          | 0/47 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]

# %% [markdown]
# ## Useful DataFrame methods
#
# 1. Use `df.values` to get the underlying ndarray, and use `ndarray` operations.
# 2. **Use Excel, by hand or other tools you want to calculate the values.**

# %%
df_all = pd.read_csv(csv_path_all).sort_values('date')  # read all data of stock market

df_ual = df_all[df_all['symbol'] == 'UAL']              # select entries that has symbol 'UAL'
# df_ual = df_all[df_all['symbol'].isin(['UAL', 'WU'])] # another way, but can select multiple companies
df_ual = df_ual.reset_index(drop=True)                  # Reset the index to 0, 1, ..., 1761

print(df_ual)

df_ual = df_ual.drop(columns=['symbol', 'date'])        # drop symbol & date columns
data_ual = df_ual.values                                # get its underlying ndarray

print(data_ual.shape)
print(data_ual[:10])
# Out:
#             date symbol       open      close        low       high  \
# 0     2010-01-04    UAL  12.990000  12.800000  12.530000  13.110000
# 1     2010-01-05    UAL  12.870000  13.910000  12.870000  14.100000
# 2     2010-01-06    UAL  13.740000  13.270000  13.130000  13.990000
# 3     2010-01-07    UAL  13.200000  13.550000  13.200000  13.950000
# 4     2010-01-08    UAL  13.560000  13.330000  13.130000  13.860000
# ...          ...    ...        ...        ...        ...        ...
# 1757  2016-12-23    UAL  74.400002  74.790001  74.129997  74.830002
# 1758  2016-12-27    UAL  74.779999  74.669998  74.500000  75.220001
# 1759  2016-12-28    UAL  75.000000  73.529999  73.349998  75.180000
# 1760  2016-12-29    UAL  73.529999  73.279999  72.930000  74.190002
# 1761  2016-12-30    UAL  73.430000  72.879997  72.370003  73.430000
#
#           volume
# 0      8785900.0
# 1     23646300.0
# 2     15398700.0
# 3     10177000.0
# 4      5896400.0
# ...          ...
# 1757   1616800.0
# 1758   1092400.0
# 1759   1935400.0
# 1760   1272400.0
# 1761   1704600.0
#
# [1762 rows x 7 columns]
# (1762, 5)
# [[1.29900e+01 1.28000e+01 1.25300e+01 1.31100e+01 8.78590e+06]
#  [1.28700e+01 1.39100e+01 1.28700e+01 1.41000e+01 2.36463e+07]
#  [1.37400e+01 1.32700e+01 1.31300e+01 1.39900e+01 1.53987e+07]
#  [1.32000e+01 1.35500e+01 1.32000e+01 1.39500e+01 1.01770e+07]
#  [1.35600e+01 1.33300e+01 1.31300e+01 1.38600e+01 5.89640e+06]
#  [1.33600e+01 1.31100e+01 1.26600e+01 1.34200e+01 1.01686e+07]
#  [1.30000e+01 1.26900e+01 1.25900e+01 1.31600e+01 7.20330e+06]
#  [1.27500e+01 1.39500e+01 1.25300e+01 1.40500e+01 2.50974e+07]
#  [1.38400e+01 1.39300e+01 1.36500e+01 1.41100e+01 8.79430e+06]
#  [1.39300e+01 1.32500e+01 1.32200e+01 1.40700e+01 1.02107e+07]]

# %%
df_all = pd.read_csv(csv_path_all).sort_values('date')  # read all data of stock market
df_all = df_all.drop(columns=['date'])

for symbol, group in df_all.groupby('symbol'):          # iterate different companies. group is a DataFrame that is subset of df_all
    print('symbol:', symbol, 'shape:', group.shape)
    print(group.sample(3))                              # print random 3 entries
    group = group.drop(columns=['symbol'])              # drop symbol columns
    print('mean:', group.mean(axis=0).values)           # compute mean of rest columns respectively
    print('-' * 10)
# Out:
# symbol: A shape: (1762, 6)
#        symbol       open      close        low       high     volume
# 808085      A  47.230000  47.000000  46.889999  47.389999  1424500.0
# 676676      A  39.110001  39.020000  39.000000  40.349998  6416900.0
# 547341      A  39.892704  40.107296  39.749642  40.343350  2238700.0
# mean: [3.40652898e+01 3.40802207e+01 3.37141014e+01 3.44148416e+01
#  3.92758910e+06]
# ----------
# symbol: AAL shape: (1762, 6)
#        symbol       open      close        low       high     volume
# 404270    AAL  17.780001  17.650000  17.559999  18.200001  4543800.0
# 436878    AAL  16.860001  17.469999  16.840000  17.469999  5276200.0
# 136898    AAL   7.940000   7.970000   7.710000   8.080000  8529800.0
# mean: [2.38751078e+01 2.38737684e+01 2.34664529e+01 2.42839331e+01
#  9.35403802e+06]
# ----------
# symbol: AAP shape: (1762, 6)
#        symbol       open      close        low       high     volume
# 289324    AAP  70.820000  70.660004  70.230003  72.680000  1498700.0
# 325906    AAP  68.370003  69.489998  68.110001  69.650002   631200.0
# 263529    AAP  90.699997  90.510002  90.269997  91.050003   853800.0
# mean: [1.03724540e+02 1.03769597e+02 1.02685749e+02 1.04800505e+02
#  1.02202645e+06]
# ----------
# symbol: AAPL shape: (1762, 6)
#        symbol        open       close         low       high       volume
# 556146   AAPL  101.019997  102.129997  100.699997  102.57000   52369000.0
# 270565   AAPL   87.674286   86.905716   86.101425   88.60714  238632800.0
# 671223   AAPL  121.500000  118.440002  117.519997  122.57000   69976000.0
# mean: [7.94277445e+01 7.94026828e+01 7.86400340e+01 8.01404467e+01
#  9.42257759e+07]
# ----------
# symbol: ABBV shape: (1008, 6)
#        symbol       open      close        low       high      volume
# 393647   ABBV  45.680000  43.990002  43.860001  45.680000   9649400.0
# 598201   ABBV  66.769997  66.300003  66.019997  67.160004   5568800.0
# 541966   ABBV  53.209999  53.520000  52.880001  55.000000  18699000.0
# mean: [5.54410813e+01 5.54736409e+01 5.48293254e+01 5.60681648e+01
#  8.47078879e+06]
# ----------
# symbol: ABC shape: (1762, 6)
#        symbol        open       close        low        high     volume
# 756255    ABC   87.300003   86.660004  86.599998   88.000000  2218700.0
# 458354    ABC   66.919998   68.000000  66.750000   68.019997  1504500.0
# 680153    ABC  101.470001  101.150002  99.400002  101.790001  4173800.0
# mean: [6.09402554e+01 6.09577469e+01 6.04231612e+01 6.14542906e+01
#  2.46025596e+06]
# ----------
# symbol: ABT shape: (1762, 6)
#        symbol       open      close        low       high      volume
# 200217    ABT  24.277858  24.268262  24.124322  24.373819  12012500.0
# 64760     ABT  23.519775  23.514977  23.203108  23.769272  22413000.0
# 242427    ABT  26.806402  26.734432  26.614482  26.806402  12147700.0
# mean: [3.46219356e+01 3.46284910e+01 3.43555739e+01 3.48854305e+01
#  1.10703591e+07]
# ----------
# symbol: ACN shape: (1762, 6)
#        symbol       open      close        low       high      volume
# 272444    ACN  63.160000  62.820000  62.700001  63.689999   3056800.0
# 56337     ACN  39.400002  40.549999  39.240002  41.130001  53159900.0
# 684619    ACN  95.389999  96.809998  95.360001  97.360001   3342100.0
# mean: [7.51293984e+01 7.52118842e+01 7.45667367e+01 7.57673837e+01
#  3.39268808e+06]
# ----------
# symbol: ADBE shape: (1762, 6)
#        symbol   open      close        low       high     volume
# 542948   ADBE  72.50  71.959999  71.699997  72.650002  1906100.0
# 595271   ADBE  75.00  74.449997  73.989998  75.239998  6969500.0
# 199281   ADBE  24.73  24.639999  24.430000  25.100000  6805600.0
# mean: [5.52128831e+01 5.52479115e+01 5.46692395e+01 5.57602667e+01
#  4.59285375e+06]
# ----------
# symbol: ADI shape: (1762, 6)
#        symbol       open      close        low       high     volume
# 51659     ADI  28.110001  29.040001  28.110001  29.110001  3395000.0
# 613481    ADI  56.840000  57.049999  56.500000  57.240002  1404300.0
# 223670    ADI  34.029999  33.320000  32.930000  34.250000  5792500.0
# mean: [4.63336663e+01 4.63496367e+01 4.58610613e+01 4.67778207e+01
#  2.81326816e+06]
# ----------
# symbol: ADM shape: (1762, 6)
#        symbol       open      close        low       high     volume
# 88632     ADM  31.930000  31.610001  31.440001  32.040001  5079200.0
# 203973    ADM  25.190001  25.190001  25.010000  25.600000  6938900.0
# 303401    ADM  27.330000  27.540001  27.059999  27.700001  4181000.0
# mean: [3.67909421e+01 3.67998241e+01 3.64474858e+01 3.71336606e+01
#  4.56769467e+06]
# ----------
# symbol: ADP shape: (1762, 6)
#        symbol       open      close        low       high     volume
# 324507    ADP  51.395964  51.369624  51.229152  51.747149  2293600.0
# 216637    ADP  45.223883  44.503954  44.302024  45.259001  4792000.0
# 390273    ADP  57.892890  58.261637  57.427570  58.287975  1444800.0
# mean: [6.25941054e+01 6.26284728e+01 6.21413232e+01 6.30207139e+01
#  2.44010437e+06]
# ----------
# symbol: ADS shape: (1762, 6)
#        symbol        open       close         low        high     volume
# 469602    ADS  248.000000  245.970001  240.399994  248.270004  1164500.0
# 164579    ADS   88.739998   89.099998   88.440002   89.809998   547100.0
# 341392    ADS  140.839996  140.830002  140.190002  141.020004   212500.0
# mean: [1.77285329e+02 1.77362838e+02 1.75412241e+02 1.79152389e+02
#  7.37654427e+05]
# ----------
# symbol: ADSK shape: (1762, 6)
#        symbol       open      close        low       high     volume
# 705472   ADSK  62.540001  63.509998  62.389999  63.630001  3820200.0
# 639614   ADSK  57.110001  57.590000  56.750000  57.680000  2042900.0
# 271512   ADSK  40.669998  40.419998  40.410000  41.009998  1986500.0
# mean: [4.46215040e+01 4.46604200e+01 4.40750397e+01 4.51874404e+01
#  2.91837123e+06]
# ----------
# symbol: AEE shape: (1762, 6)
#        symbol       open      close        low       high     volume
# 79276     AEE  28.790001  28.650000  28.459999  28.790001  3029900.0
# 73192     AEE  28.240000  27.969999  27.959999  28.520000  3847700.0
# 800115    AEE  51.020000  51.020000  50.709999  51.160000   875200.0
# mean: [3.62513110e+01 3.62703632e+01 3.59638195e+01 3.65410046e+01
#  1.75975386e+06]
# ----------
# symbol: AEP shape: (1762, 6)
#        symbol       open      close    low       high     volume
# 135504    AEP  35.220001  35.279999  35.02  35.349998  1499200.0
# 65237     AEP  35.750000  35.799999  35.52  36.000000  4021600.0
# 669251    AEP  55.639999  55.889999  55.52  56.029999  2687100.0
# mean: [4.75443757e+01 4.75572701e+01 4.71814869e+01 4.78895800e+01
#  3.14973314e+06]
# ----------
# symbol: AES shape: (1762, 6)
#        symbol   open  close    low   high     volume
# 393659    AES  13.86  13.83  13.70  13.88  3763500.0
# 674708    AES  12.33  13.06  12.33  13.10  7759600.0
# 168335    AES  12.34  12.33  12.23  12.45  5616300.0
# mean: [1.22429682e+01 1.22433485e+01 1.20980931e+01 1.23829398e+01
#  5.80178082e+06]
# ----------
# symbol: AET shape: (1762, 6)
#        symbol       open      close        low       high     volume
# 129878    AET  37.009998  37.639999  36.849998  38.099998  5999700.0
# 476453    AET  67.680000  67.849998  67.669998  68.260002   810800.0
# 150983    AET  37.990002  37.439999  37.259998  37.990002  3236000.0
# mean: [6.76136663e+01 6.76376504e+01 6.68897560e+01 6.83445006e+01
#  3.54960403e+06]
# ----------
# symbol: AFL shape: (1762, 6)
#        symbol       open      close        low       high     volume
# 689590    AFL  56.830002  57.490002  56.830002  57.630001  2220100.0
# 527799    AFL  61.980000  61.950001  61.610001  62.049999  1793800.0
# 357449    AFL  53.000000  52.950001  52.349998  53.250000  1611900.0
# mean: [5.61332406e+01 5.61469012e+01 5.56289784e+01 5.66166743e+01
#  2.88181135e+06]
# ----------
# symbol: AGN shape: (1762, 6)
#        symbol        open       close         low        high     volume
# 257917    AGN   58.500000   59.610001   58.290001   60.000000  1349200.0
# 425678    AGN  136.479996  135.619995  134.600006  137.119995   772100.0
# 338116    AGN   84.900002   84.480003   84.309998   85.430000   913800.0
# mean: [1.51899563e+02 1.51837100e+02 1.49982157e+02 1.53670976e+02
#  2.23373462e+06]
# ----------
# symbol: AIG shape: (1762, 6)
#        symbol   open      close        low       high      volume
# 16614     AIG  27.16  27.990000  26.860001  28.459999  12118400.0
# 171153    AIG  28.17  27.889999  27.680000  28.610001   9563600.0
# 352187    AIG  35.50  34.970001  34.400002  35.500000  16674800.0
# mean: [4.46199773e+01 4.46208967e+01 4.41209705e+01 4.51222702e+01
#  1.04925884e+07]
# ----------
# symbol: AIV shape: (1762, 6)
#        symbol       open      close        low   high     volume
# 410561    AIV  27.920000  27.559999  27.440001  28.00  1825900.0
# 373356    AIV  29.520000  29.760000  29.330000  29.82  1253200.0
# 706452    AIV  36.220001  36.470001  36.209999  36.82  1824200.0
# mean: [3.04364075e+01 3.04574461e+01 3.01303292e+01 3.07477469e+01
#  1.46834563e+06]
# ----------
# symbol: AIZ shape: (1762, 6)
#        symbol       open      close        low       high     volume
# 351250    AIZ  34.709999  34.820000  34.660000  35.189999   229300.0
# 245725    AIZ  39.779999  40.509998  39.610001  40.770000  1214900.0
# 380140    AIZ  44.090000  44.020000  43.580002  44.200001  1372400.0
# mean: [5.46896878e+01 5.47330363e+01 5.42369751e+01 5.51954540e+01
#  8.34912997e+05]
# ----------
# symbol: AJG shape: (1762, 6)
#        symbol       open      close        low       high     volume
# 19418     AJG  24.389999  24.170000  24.020000  24.500000   482800.0
# 263079    AJG  35.500000  35.990002  35.439999  35.990002   521500.0
# 746312    AJG  40.980000  41.090000  40.759998  41.169998  1018300.0
# mean: [3.88233428e+01 3.88394211e+01 3.85494722e+01 3.90901703e+01
#  7.77513791e+05]
# ----------
# symbol: AKAM shape: (1762, 6)
#        symbol       open      close        low       high     volume
# 144892   AKAM  38.660000  38.450001  38.250000  39.299999  6459000.0
# 149582   AKAM  37.750000  37.349998  37.150002  37.930000  3011400.0
# 428117   AKAM  46.709999  46.939999  46.360001  47.189999   995000.0
# mean: [4.75362997e+01 4.75562656e+01 4.69483598e+01 4.81335358e+01
#  3.09855664e+06]
# ----------
# symbol: ALB shape: (1762, 6)
#        symbol       open      close        low       high     volume
# 168343    ALB  66.330002  66.040001  65.760002  67.300003   790200.0
# 122381    ALB  58.480000  59.860001  58.220001  60.540001  1021700.0
# 132230    ALB  57.459999  57.770000  57.380001  57.849998   581900.0
# mean: [5.95194155e+01 5.95311010e+01 5.88346708e+01 6.01995743e+01
#  1.01109421e+06]
# ----------
# symbol: ALK shape: (1762, 6)
#        symbol       open      close        low       high     volume
# 636175    ALK  64.940002  64.309998  63.660000  65.000000  1280600.0
# 159433    ALK  17.190001  17.222500  17.112499  17.415001  1539600.0
# 44655     ALK  10.907500  10.585000  10.577500  11.177500  3647600.0
# mean: [3.80113664e+01 3.80333797e+01 3.75046127e+01 3.85191785e+01
#  1.62866305e+06]
# ----------
# symbol: ALL shape: (1762, 6)
#        symbol       open      close        low       high     volume
# 583553    ALL  67.010002  66.580002  66.430000  67.010002  1559600.0
# 177725    ALL  30.639999  30.620001  30.410000  30.790001  3142100.0
# 158027    ALL  33.849998  33.419998  33.220001  33.950001  5249900.0
# mean: [4.81289898e+01 4.81520829e+01 4.77935698e+01 4.84837458e+01
#  3.42952855e+06]
# ----------
# symbol: ALLE shape: (786, 6)
#        symbol       open      close        low       high     volume
# 755281   ALLE  64.550003  64.699997  64.070000  65.220001   979000.0
# 491622   ALLE  49.840000  49.160000  49.029999  50.340000  1076100.0
# 683151   ALLE  59.049999  58.720001  58.270000  59.250000   421400.0
# mean: [5.89791095e+01 5.89987787e+01 5.83990713e+01 5.95445929e+01
#  7.56796310e+05]
# ----------
# symbol: ALXN shape: (1762, 6)
#        symbol        open       close         low        high     volume
# 382561   ALXN   91.070000   95.599998   91.070000   95.860001  2538000.0
# 340469   ALXN   92.089996   94.059998   91.830002   94.089996  1124600.0
# 765242   ALXN  141.710007  144.369995  141.000000  147.789993  2259300.0
# mean: [1.08809291e+02 1.08807245e+02 1.07016654e+02 1.10422072e+02
#  1.55765278e+06]
# ----------
# symbol: AMAT shape: (1762, 6)
#        symbol   open      close        low       high      volume
# 581600   AMAT  22.43  22.629999  22.360001  22.959999  10653900.0
# 781179   AMAT  23.65  23.430000  23.360001  23.650000  22138500.0
# 230255   AMAT  10.57  10.500000  10.430000  10.660000  26733000.0
# mean: [1.68038593e+01 1.68080817e+01 1.66107718e+01 1.69952100e+01
#  1.56333651e+07]
# ----------
# symbol: AME shape: (1762, 6)
#        symbol       open      close        low       high     volume
# 392223    AME  40.790001  40.549999  40.450001  40.799999  1508800.0
# 404781    AME  42.820000  42.669998  42.400002  43.150002  2092000.0
# 359870    AME  39.360001  39.830002  39.330002  39.919998  1215500.0
# mean: [3.96980659e+01 3.97227822e+01 3.93558696e+01 4.00351047e+01
#  1.21672037e+06]
# ----------
# symbol: AMG shape: (1762, 6)
#        symbol        open       close         low        high    volume
# 380632    AMG  152.279999  151.539993  150.520004  152.860001  342300.0
# 434955    AMG  177.289993  175.660004  173.860001  178.820007  639500.0
# 720425    AMG  155.289993  157.919998  153.710007  158.389999  529600.0
# mean: [1.43493218e+02 1.43500414e+02 1.41876544e+02 1.45009779e+02
#  4.76618956e+05]
# ----------
# symbol: AMGN shape: (1762, 6)
#        symbol        open       close         low        high     volume
# 644563   AMGN  163.270004  162.360001  161.679993  163.630005  2384600.0
# 659850   AMGN  153.240005  153.520004  151.509995  154.220001  3893300.0
# 450084   AMGN  112.419998  114.279999  112.349998  114.849998  3541600.0
# mean: [1.05343984e+02 1.05355647e+02 1.04238876e+02 1.06393837e+02
#  4.66560471e+06]
# ----------
# symbol: AMP shape: (1762, 6)
#        symbol        open       close         low        high     volume
# 820094    AMP  102.720001  101.160004  100.620003  102.720001   903000.0
# 560577    AMP  125.410004  125.599998  124.889999  126.080002   688000.0
# 768733    AMP   95.870003   95.339996   94.309998   96.709999  1060300.0
# mean: [8.21515607e+01 8.21845459e+01 8.13527810e+01 8.29433938e+01
#  1.60600880e+06]
# ----------
# symbol: AMT shape: (1762, 6)
#        symbol        open       close         low        high     volume
# 792151    AMT  117.360001  117.730003  117.099998  117.839996  1627400.0
# 753296    AMT  102.349998  102.309998  102.080002  102.910004  1568400.0
# 640621    AMT   94.650002   93.000000   92.860001   94.980003  3092800.0
# mean: [7.66200057e+01 7.66454199e+01 7.59843701e+01 7.72576560e+01
#  2.67292594e+06]
# ----------
# symbol: AMZN shape: (1762, 6)
#        symbol        open       close         low        high     volume
# 131771   AMZN  189.250000  190.419998  188.350006  191.399994  4061300.0
# 299673   AMZN  217.449997  216.929993  213.960007  217.940002  1987000.0
# 774213   AMZN  715.000000  712.239990  711.099976  716.599976  2246400.0
# mean: [3.37875664e+02 3.37899058e+02 3.33969688e+02 3.41464438e+02
#  4.60759597e+06]
# ----------
# symbol: AN shape: (1762, 6)
#        symbol   open      close        low       high    volume
# 433496     AN  45.27  45.369999  44.919998  45.619999  437400.0
# 424720     AN  49.00  49.290001  48.619999  49.490002  718500.0
# 115357     AN  27.99  28.100000  27.969999  28.340000  439600.0
# mean: [4.36579966e+01 4.36672191e+01 4.31580817e+01 4.41674915e+01
#  1.11730278e+06]
# ----------
# symbol: ANTM shape: (1762, 6)
#        symbol       open      close        low   high     volume
# 23168    ANTM  61.430000  61.970001  60.669998  62.02  4710100.0
# 190398   ANTM  61.439999  60.380001  59.730000  61.66  4288000.0
# 332505   ANTM  62.330002  61.580002  61.490002  62.57  1963200.0
# mean: [9.37258569e+01 9.37849433e+01 9.27644154e+01 9.47323156e+01
#  2.76635216e+06]
# ----------
# symbol: AON shape: (1762, 6)
#        symbol        open       close         low        high     volume
# 830578    AON  109.480003  111.389999  109.330002  111.449997  1592900.0
# 662330    AON   99.180000   99.260002   99.070000  100.120003  1475800.0
# 694570    AON   90.879997   91.930000   90.430000   92.089996   793600.0
# mean: [7.06876220e+01 7.07462600e+01 7.01981953e+01 7.12290011e+01
#  1.77181288e+06]
# ----------
# symbol: APA shape: (1762, 6)
#        symbol       open      close        low       high     volume
# 613511    APA  65.860001  67.050003  65.160004  67.089996  5850600.0
# 775213    APA  56.490002  56.169998  55.180000  56.860001  3818400.0
# 840559    APA  65.620003  66.349998  64.059998  66.760002  2148300.0
# mean: [8.24838706e+01 8.24489330e+01 8.14005846e+01 8.34458910e+01
#  3.65186271e+06]
# ----------
# symbol: APC shape: (1762, 6)
#        symbol       open      close        low       high     volume
# 489679    APC  82.050003  81.690002  81.230003  82.620003  2411500.0
# 839562    APC  68.410004  68.559998  68.050003  69.470001  3669000.0
# 485767    APC  80.489998  80.690002  80.320000  81.239998  3041400.0
# mean: [7.41654257e+01 7.41477923e+01 7.30935812e+01 7.51524802e+01
#  4.95098065e+06]
# ----------
# symbol: APD shape: (1762, 6)
#        symbol        open       close         low        high     volume
# 511196    APD  108.381123  109.787228  108.094357  109.814984  1834400.0
# 387887    APD   78.778906   80.018500   78.778906   80.092504  1006300.0
# 274822    APD   78.464384   79.666975   78.390378   80.342276  1553100.0
# mean: [1.00327047e+02 1.00341852e+02 9.94654946e+01 1.01128874e+02
#  1.44253984e+06]
# ----------
# symbol: APH shape: (1762, 6)
#        symbol       open      close        low   high     volume
# 381126    APH  36.375000  36.595001  36.330002  36.61   619000.0
# 597261    APH  55.419998  55.220001  55.200001  55.66   401200.0
# 6361      APH  21.110001  20.270000  20.254999  21.25  3938800.0
# mean: [3.96649575e+01 3.96930420e+01 3.93443360e+01 3.99952100e+01
#  1.69532333e+06]
# ----------
# symbol: ARNC shape: (1762, 6)
#        symbol      open      close       low       high      volume
# 446679   ARNC  5.922043   5.974517  5.877066   5.997006  16351500.0
# 81644    ARNC  8.530741   8.635689  8.493259   8.688163  10950200.0
# 12900    ARNC  9.887564  10.179918  9.835090  10.232391  15218400.0
# mean: [9.02456777e+00 9.01539621e+00 8.89393826e+00 9.14004042e+00
#  1.08961551e+07]
# ----------
# symbol: ATVI shape: (1762, 6)
#        symbol       open  close    low       high     volume
# 593351   ATVI  20.100000  20.02  19.82  20.290001  5744600.0
# 760776   ATVI  35.340000  35.25  34.93  35.450001  3502300.0
# 474035   ATVI  18.200001  18.08  17.98  18.290001  3318400.0
# mean: [1.94895176e+01 1.94905675e+01 1.92534676e+01 1.97139160e+01
#  8.98397162e+06]
# ----------
# symbol: AVB shape: (1762, 6)
#        symbol        open       close         low        high     volume
# 351742    AVB  136.830002  135.059998  134.789993  136.910004   692800.0
# 258411    AVB  137.789993  138.759995  137.679993  139.600006  1367900.0
# 504843    AVB  130.179993  130.130005  129.750000  130.960007   854200.0
# mean: [1.40108564e+02 1.40161532e+02 1.38796527e+02 1.41402815e+02
#  8.52279001e+05]
# ----------
# symbol: AVGO shape: (1762, 6)
#        symbol       open      close        low       high     volume
# 443266   AVGO  42.470001  42.270000  42.040001  42.660000  1687400.0
# 363260   AVGO  35.520000  35.770000  35.250000  36.090000  6776400.0
# 462790   AVGO  42.930000  43.049999  42.720001  43.220001  1543400.0
# mean: [6.90567480e+01 6.90696367e+01 6.80945687e+01 6.99418729e+01
#  2.42743297e+06]
# ----------
# symbol: AVY shape: (1762, 6)
#        symbol       open      close        low       high     volume
# 778707    AVY  76.080002  77.110001  76.000000  77.250000   678900.0
# 198850    AVY  27.250000  26.860001  26.799999  27.590000   655700.0
# 218079    AVY  26.580000  26.610001  26.080000  26.780001  1146800.0
# mean: [4.63145574e+01 4.63302497e+01 4.58885244e+01 4.67431044e+01
#  9.43623723e+05]
# ----------
# symbol: AWK shape: (1762, 6)
#        symbol       open      close        low       high     volume
# 760780    AWK  72.300003  70.879997  70.830002  72.400002  1171200.0
# 116307    AWK  25.459999  25.510000  25.209999  25.530001   491100.0
# 746338    AWK  68.269997  68.690002  68.080002  68.980003  1495500.0
# mean: [4.31552157e+01 4.31670374e+01 4.28056924e+01 4.34927355e+01
#  9.94058002e+05]
# ----------
# symbol: AXP shape: (1762, 6)
#        symbol       open      close        low       high     volume
# 721439    AXP  69.739998  70.160004  69.739998  70.510002  1956400.0
# 83054     AXP  40.790001  40.959999  40.580002  41.119999  7239800.0
# 77906     AXP  39.730000  39.869999  39.470001  40.389999  8312900.0
# mean: [6.42148127e+01 6.42320375e+01 6.36732691e+01 6.47587174e+01
#  6.42205936e+06]
# ----------
# symbol: AYI shape: (1762, 6)
#        symbol        open       close         low        high    volume
# 674246    AYI  208.399994  211.149994  206.550003  211.539993  488600.0
# 116778    AYI   58.950001   58.959999   58.790001   59.240002  265300.0
# 658880    AYI  182.089996  182.270004  180.949997  183.000000  375900.0
# mean: [1.13659745e+02 1.13740136e+02 1.12368910e+02 1.14955885e+02
#  4.12259137e+05]
# ----------
# symbol: AZO shape: (1762, 6)
#        symbol        open       close         low        high    volume
# 613523    AZO  614.130005  618.500000  611.679993  619.619995  164400.0
# 179625    AZO  293.209991  297.589996  293.100006  299.600006  392400.0
# 22248     AZO  168.729996  168.889999  168.089996  169.330002  256600.0
# mean: [   468.84518748    469.00774677    464.98973352    472.68898409
#  357881.55505108]
# ----------
# symbol: BA shape: (1762, 6)
#        symbol        open       close         low        high     volume
# 741860     BA  116.349998  116.820000  115.779999  117.599998  4667100.0
# 218084     BA   65.589996   65.800003   65.000000   65.949997  3458000.0
# 197917     BA   61.910000   62.770000   61.220001   62.900002  6478800.0
# mean: [1.02448286e+02 1.02479852e+02 1.01547372e+02 1.03336793e+02
#  4.81043519e+06]
# ----------
# symbol: BAC shape: (1762, 6)
#        symbol   open  close    low   high       volume
# 171654    BAC  10.45  10.60  10.40  10.69  200127400.0
# 430585    BAC  14.18  14.29  13.98  14.38  114332500.0
# 442297    BAC  14.18  14.09  14.01  14.25   96912800.0
# mean: [1.35846084e+01 1.35726901e+01 1.34204654e+01 1.37320318e+01
#  1.42386970e+08]
# ----------
# symbol: BAX shape: (1762, 6)
#        symbol       open      close        low       high     volume
# 420355    BAX  40.244430  40.429115  40.021728  40.445411  4751900.0
# 781204    BAX  44.630001  44.439999  44.000000  44.669998  5158100.0
# 86803     BAX  26.040195  26.045627  25.882672  26.127105  6324700.0
# mean: [3.52003708e+01 3.52035466e+01 3.49202299e+01 3.54706913e+01
#  6.61730783e+06]
# ----------
# symbol: BBBY shape: (1762, 6)
#        symbol       open      close        low       high     volume
# 504853   BBBY  67.550003  68.430000  67.459999  68.449997  1421900.0
# 665819   BBBY  69.220001  68.250000  68.099998  69.320000  1250400.0
# 331585   BBBY  60.150002  60.380001  59.889999  60.570000  2315000.0
# mean: [5.82892225e+01 5.83002327e+01 5.77165494e+01 5.88808457e+01
#  2.61813144e+06]
# ----------
# symbol: BBT shape: (1762, 6)
#        symbol   open      close        low       high     volume
# 448156    BBT  33.16  33.689999  33.160000  33.689999  3708000.0
# 378242    BBT  30.66  30.750000  30.559999  30.879999  5127400.0
# 608598    BBT  35.27  35.290001  35.080002  35.950001  5468800.0
# mean: [3.27101475e+01 3.27271510e+01 3.24116288e+01 3.30091601e+01
#  4.97345153e+06]
# ----------
# symbol: BBY shape: (1762, 6)
#        symbol       open      close    low   high      volume
# 266396    BBY  23.360001  22.950001  22.76  23.98  10274400.0
# 283280    BBY  18.680000  19.170000  18.68  19.25   5633600.0
# 357487    BBY  14.000000  14.480000  13.92  14.67  19677200.0
# mean: [3.10877469e+01 3.10888820e+01 3.06606924e+01 3.15157321e+01
#  6.80466481e+06]
# ----------
# symbol: BCR shape: (1762, 6)
#        symbol        open       close         low        high    volume
# 586519    BCR  166.970001  167.649994  166.679993  167.750000  239900.0
# 147740    BCR  100.910004  100.470001  100.400002  101.250000  493000.0
# 670782    BCR  194.289993  196.649994  193.729996  196.850006  919200.0
# mean: [1.32780630e+02 1.32873984e+02 1.31756243e+02 1.33867724e+02
#  6.29480477e+05]
# ----------
# symbol: BDX shape: (1762, 6)
#        symbol        open       close         low        high     volume
# 471605    BDX  106.059998  108.550003  105.529999  108.720001  1158300.0
# 367619    BDX   88.889999   88.470001   88.239998   89.160004  1095100.0
# 821617    BDX  175.149994  173.470001  173.279999  175.149994   973200.0
# mean: [1.08133167e+02 1.08162985e+02 1.07342701e+02 1.08881742e+02
#  1.13647350e+06]
# ----------
# symbol: BEN shape: (1762, 6)
#        symbol       open      close        low       high     volume
# 495078    BEN  52.910000  53.250000  52.639999  53.560001  2883000.0
# 126168    BEN  40.606667  40.910000  40.326668  41.333332  4372200.0
# 418413    BEN  48.136665  48.299999  48.070000  48.660000  2954700.0
# mean: [4.30471510e+01 4.30561143e+01 4.26197181e+01 4.34601759e+01
#  2.91641515e+06]
# ----------
# symbol: BHI shape: (1762, 6)
#        symbol       open      close        low       high     volume
# 751331    BHI  46.230000  44.959999  44.919998  46.599998  2057400.0
# 821619    BHI  52.270000  52.200001  51.950001  52.639999  3404300.0
# 447185    BHI  49.099998  48.930000  48.910000  49.500000  2400200.0
# mean: [5.34039898e+01 5.34034222e+01 5.26510272e+01 5.41252213e+01
#  4.81236975e+06]
# ----------
# symbol: BIIB shape: (1762, 6)
#        symbol        open       close         low        high     volume
# 689634   BIIB  295.579987  293.010010  287.119995  298.149994  2663100.0
# 141647   BIIB   69.139999   68.699997   68.309998   69.680000  2325100.0
# 268277   BIIB  125.720001  125.029999  125.029999  127.550003  1793000.0
# mean: [2.07431629e+02 2.07351390e+02 2.04648587e+02 2.10096759e+02
#  1.83292900e+06]
# ----------
# symbol: BK shape: (1762, 6)
#        symbol       open      close        low       high     volume
# 116791     BK  30.389999  30.280001  30.270000  30.530001  2507900.0
# 505839     BK  35.810001  35.410000  35.180000  35.860001  5115900.0
# 456459     BK  32.400002  32.509998  32.209999  32.599998  5839600.0
# mean: [3.19115607e+01 3.19201590e+01 3.16139841e+01 3.22072985e+01
#  6.83261566e+06]
# ----------
# symbol: BLK shape: (1762, 6)
#        symbol        open       close         low        high    volume
# 588481    BLK  356.720001  355.029999  353.880005  357.739990  584500.0
# 250457    BLK  192.679993  189.880005  189.429993  192.949997  781500.0
# 551317    BLK  312.929993  313.000000  311.700012  314.250000  383600.0
# mean: [2.61828593e+02 2.61790840e+02 2.59159291e+02 2.64266924e+02
#  7.36174631e+05]
# ----------
# symbol: BLL shape: (1762, 6)
#        symbol       open      close        low       high     volume
# 676741    BLL  71.089996  71.610001  71.089996  71.800003   413100.0
# 188081    BLL  35.680000  35.439999  34.169998  35.930000  3113400.0
# 668805    BLL  66.910004  66.639999  66.220001  66.970001   659900.0
# mean: [5.07440692e+01 5.07800794e+01 5.03227639e+01 5.11654853e+01
#  1.23616703e+06]
# ----------
# symbol: BMY shape: (1762, 6)
#        symbol       open      close        low       high      volume
# 174950    BMY  29.030001  28.469999  28.330000  29.120001  19192000.0
# 369075    BMY  36.580002  36.939999  36.580002  36.980000   5517200.0
# 165101    BMY  28.170000  28.410000  28.110001  28.459999   7890600.0
# mean: [4.45185641e+01 4.45322248e+01 4.41184959e+01 4.49208684e+01
#  9.60525068e+06]
# ----------
# symbol: BSX shape: (1762, 6)
#        symbol   open  close    low   high      volume
# 251867    BSX   6.12   5.98   5.97   6.14  15186700.0
# 8721      BSX   8.74   8.63   8.62   8.82  12241400.0
# 489706    BSX  12.83  12.96  12.83  13.04   9368100.0
# mean: [1.14275482e+01 1.14294892e+01 1.12945914e+01 1.15554994e+01
#  1.50838187e+07]
# ----------
# symbol: BWA shape: (1762, 6)
#        symbol       open      close        low       high     volume
# 577727    BWA  57.369999  56.860001  56.380001  58.000000  1848600.0
# 560123    BWA  62.290001  61.820000  61.709999  62.630001  1161500.0
# 529805    BWA  65.639999  66.080002  65.500000  66.190002   789400.0
# mean: [4.07267651e+01 4.07429824e+01 4.02328944e+01 4.12161408e+01
#  2.50880040e+06]
# ----------
# symbol: BXP shape: (1762, 6)
#        symbol        open       close         low        high    volume
# 32540     BXP   80.680000   80.129997   79.589996   80.709999  952400.0
# 566481    BXP  112.839996  115.250000  112.750000  115.669998  984500.0
# 776239    BXP  127.930000  127.779999  126.879997  128.660004  737000.0
# mean: [1.08999591e+02 1.09038434e+02 1.08020982e+02 1.09939739e+02
#  9.74130477e+05]
# ----------
# symbol: C shape: (1762, 6)
#        symbol   open      close        low       high      volume
# 214350      C  31.40  30.900000  30.450001  31.500000  65217200.0
# 583108      C  53.48  53.439999  52.980000  53.580002  12668400.0
# 564037      C  53.98  53.480000  53.259998  54.130001  22153100.0
# mean: [4.39910783e+01 4.39750795e+01 4.34845517e+01 4.44634506e+01
#  3.37081221e+07]
# ----------
# symbol: CA shape: (1762, 6)
#        symbol       open      close        low   high     volume
# 740385     CA  30.230000  29.530001  29.410000  30.25  4165100.0
# 483842     CA  32.279999  32.240002  32.099998  32.57  4678000.0
# 31141      CA  22.830000  22.940001  22.780001  22.98  3606700.0
# mean: [2.69569977e+01 2.69650851e+01 2.67114472e+01 2.71930080e+01
#  3.54242440e+06]
# ----------
# symbol: CAG shape: (1762, 6)
#        symbol       open      close        low       high     volume
# 77929     CAG  16.684823  16.801555  16.607004  16.856031  5697400.0
# 304400    CAG  19.276264  19.214008  19.112840  19.291828  5232500.0
# 325974    CAG  21.649805  21.657587  21.525291  21.735409  3320300.0
# mean: [2.50286952e+01 2.50439664e+01 2.48463697e+01 2.52167002e+01
#  4.69872162e+06]
# ----------
# symbol: CAH shape: (1762, 6)
#        symbol       open      close        low       high     volume
# 608615    CAH  84.589996  83.190002  83.059998  85.529999  3039300.0
# 204504    CAH  42.230000  43.349998  41.610001  43.369999  3814600.0
# 61550     CAH  34.689999  35.349998  34.689999  35.520000  5019100.0
# mean: [5.78718616e+01 5.78886210e+01 5.73731328e+01 5.83703291e+01
#  2.62729881e+06]
# ----------
# symbol: CAT shape: (1762, 6)
#        symbol       open      close        low       high     volume
# 777738    CAT  77.500000  78.110001  77.260002  78.699997  5987800.0
# 300650    CAT  82.959999  82.629997  82.050003  83.400002  5616100.0
# 437438    CAT  86.809998  86.610001  86.180000  86.889999  6298400.0
# mean: [8.64327581e+01 8.64291827e+01 8.55228830e+01 8.72507095e+01
#  6.69415289e+06]
# ----------
# symbol: CB shape: (1762, 6)
#        symbol        open       close         low        high     volume
# 623900     CB  113.339996  113.360001  112.699997  113.820000  1248400.0
# 454031     CB   96.070000   95.820000   95.680000   96.250000  1285000.0
# 34414      CB   52.430000   52.709999   51.919998   52.720001  1981200.0
# mean: [8.87421168e+01 8.87859705e+01 8.81299830e+01 8.93671340e+01
#  1.86249892e+06]
# ----------
# symbol: CBG shape: (1762, 6)
#        symbol       open      close        low       high     volume
# 474556    CBG  26.360001  26.240000  26.020000  26.360001  1305100.0
# 58277     CBG  13.630000  13.550000  13.070000  13.770000  5192800.0
# 615520    CBG  34.459999  34.759998  34.279999  34.840000  1397400.0
# mean: [2.47190749e+01 2.47219467e+01 2.44105902e+01 2.50120204e+01
#  3.08963541e+06]
# ----------
# symbol: CBS shape: (1762, 6)
#        symbol       open  close        low       high     volume
# 349898    CBS  36.389999  36.43  36.150002  36.830002  5575500.0
# 26944     CBS  14.050000  13.93  13.800000  14.090000  7965300.0
# 246249    CBS  28.719999  29.10  28.240000  29.320000  8832800.0
# mean: [4.13383258e+01 4.13498014e+01 4.08740408e+01 4.18071283e+01
#  7.19525278e+06]
# ----------
# symbol: CCI shape: (1762, 6)
#        symbol       open      close        low       high     volume
# 700567    CCI  85.419998  86.370003  85.129997  86.500000  2022000.0
# 514656    CCI  73.129997  71.730003  71.290001  73.139999  2530000.0
# 736408    CCI  80.750000  82.199997  80.300003  82.720001  2383700.0
# mean: [6.61264415e+01 6.61431271e+01 6.55786777e+01 6.66744041e+01
#  2.25678723e+06]
# ----------
# symbol: CCL shape: (1762, 6)
#        symbol       open      close        low       high     volume
# 769775    CCL  49.689999  49.990002  49.639999  50.180000  4432500.0
# 406762    CCL  32.189999  32.340000  32.070000  32.400002  4050200.0
# 379231    CCL  33.549999  33.639999  33.400002  33.779999  4088600.0
# mean: [4.00375823e+01 4.00368729e+01 3.96374064e+01 4.04159081e+01
#  4.55714251e+06]
# ----------
# symbol: CELG shape: (1762, 6)
#        symbol       open      close        low       high     volume
# 411615   CELG  57.200001  57.275002  56.549999  57.500000  4213000.0
# 558668   CELG  95.230003  93.930000  93.699997  95.389999  3321800.0
# 499010   CELG  78.510002  78.959999  78.375000  79.940003  5406800.0
# mean: [6.76024829e+01 6.76104966e+01 6.67117140e+01 6.84510357e+01
#  6.09726998e+06]
# ----------
# symbol: CERN shape: (1762, 6)
#        symbol       open      close        low       high     volume
# 58282    CERN  18.934999  18.934999  18.242500  19.445000  4570000.0
# 514170   CERN  51.669998  49.509998  49.169998  51.900002  6410500.0
# 534708   CERN  51.540001  52.099998  51.540001  52.270000  1387900.0
# mean: [4.52856158e+01 4.52972418e+01 4.48043672e+01 4.57533357e+01
#  2.29689154e+06]
# ----------
# symbol: CF shape: (1762, 6)
#        symbol       open      close        low       high     volume
# 807668     CF  26.110001  25.600000  25.469999  26.180000  4141100.0
# 425740     CF  38.695999  37.908001  37.299999  38.695999  7566500.0
# 810662     CF  24.920000  25.510000  24.700001  25.660000  4649100.0
# mean: [3.74960102e+01 3.74856890e+01 3.69367344e+01 3.80386266e+01
#  6.91262299e+06]
# ----------
# symbol: CFG shape: (504, 6)
#        symbol       open  close        low       high     volume
# 787709    CFG  18.990000  19.42  18.990000  19.440001  8140400.0
# 790703    CFG  21.139999  20.98  20.950001  21.270000  5157300.0
# 720477    CFG  26.160000  26.25  25.700001  26.459999  5388300.0
# mean: [2.48002877e+01 2.48117064e+01 2.45038790e+01 2.50853691e+01
#  5.91035020e+06]
# ----------
# symbol: CHD shape: (1762, 6)
#        symbol       open      close        low       high     volume
# 767290    CHD  48.494999  48.540001  48.330002  48.945000  1678200.0
# 356549    CHD  28.004999  27.875000  27.764999  28.125000  1641400.0
# 570407    CHD  34.810001  35.235000  34.689999  35.244999  1131200.0
# mean: [3.10715324e+01 3.10821638e+01 3.08454101e+01 3.12930235e+01
#  1.57475040e+06]
# ----------
# symbol: CHK shape: (1762, 6)
#        symbol       open      close        low       high     volume
# 6870      CHK  25.430465  25.506150  25.279092  25.884580  9878200.0
# 409671    CHK  20.094609  19.678336  19.668875  20.283824  8646800.0
# 536667    CHK  29.700001  29.240000  28.930000  29.920000  9808800.0
# mean: [1.88323132e+01 1.88044871e+01 1.84943106e+01 1.91241050e+01
#  1.98134448e+07]
# ----------
# symbol: CHRW shape: (1762, 6)
#        symbol   open      close        low       high     volume
# 431593   CHRW  56.52  56.919998  56.480000  57.220001   654800.0
# 570898   CHRW  66.25  65.199997  65.029999  66.650002   966800.0
# 51266    CHRW  56.75  57.439999  56.490002  57.700001  2147800.0
# mean: [6.55170658e+01 6.55545176e+01 6.49482974e+01 6.61078604e+01
#  1.51217673e+06]
# ----------
# symbol: CHTR shape: (1761, 6)
#        symbol        open       close         low        high     volume
# 298786   CHTR   72.919998   72.870003   72.699997   73.330002   236800.0
# 762811   CHTR  208.009995  210.070007  206.830002  213.320007  6694200.0
# 740899   CHTR  176.020004  174.389999  174.229996  177.789993  1893500.0
# mean: [1.17772192e+02 1.17853038e+02 1.16439404e+02 1.19182845e+02
#  1.00249983e+06]
# ----------
# symbol: CI shape: (1762, 6)
#        symbol        open       close         low        high     volume
# 802684     CI  132.039993  132.619995  132.039993  133.910004  1443900.0
# 838113     CI  136.770004  138.300003  136.770004  139.949997  1391600.0
# 807175     CI  128.250000  128.259995  127.290001  128.770004   718700.0
# mean: [7.92643076e+01 7.93213167e+01 7.84574006e+01 8.01421907e+01
#  2.29315664e+06]
# ----------
# symbol: CINF shape: (1762, 6)
#        symbol       open      close        low       high     volume
# 97133    CINF  30.240000  29.580000  29.540001  30.240000  1705700.0
# 10610    CINF  26.360001  26.260000  26.260000  26.670000  2393600.0
# 145425   CINF  32.560001  32.380001  32.369999  32.610001   634900.0
# mean: [4.50231611e+01 4.50399432e+01 4.46970488e+01 4.53278377e+01
#  8.40968388e+05]
# ----------
# symbol: CL shape: (1762, 6)
#        symbol       open      close        low       high     volume
# 424773     CL  60.259998  60.529999  60.009998  60.580002  2508800.0
# 521513     CL  66.300003  66.919998  66.300003  66.970001  2840300.0
# 431109     CL  59.000000  58.509998  58.439999  59.049999  3036800.0
# mean: [5.65297475e+01 5.65596907e+01 5.61773354e+01 5.68962174e+01
#  3.98337077e+06]
# ----------
# symbol: CLX shape: (1762, 6)
#        symbol       open      close        low       high     volume
# 340531    CLX  74.150002  74.400002  73.820000  74.500000   680500.0
# 53611     CLX  65.070000  65.209999  64.580002  65.250000   923200.0
# 129481    CLX  65.430000  65.709999  65.120003  65.760002  2847600.0
# mean: [8.84937230e+01 8.85279058e+01 8.79163962e+01 8.90869296e+01
#  1.11685738e+06]
# ----------
# symbol: CMA shape: (1762, 6)
#        symbol       open      close        low       high     volume
# 824644    CMA  51.599998  51.639999  51.139999  51.880001  3339600.0
# 614057    CMA  46.250000  46.630001  45.910000  46.630001  2080600.0
# 755346    CMA  37.509998  37.340000  37.150002  37.720001  2164500.0
# mean: [3.98699036e+01 3.98874915e+01 3.94279853e+01 4.03122475e+01
#  2.46942934e+06]
# ----------
# symbol: CMCSA shape: (1762, 6)
#        symbol       open      close        low       high      volume
# 91989   CMCSA  18.070000  18.139999  17.969999  18.219999  14756300.0
# 424776  CMCSA  45.889999  45.720001  45.389999  45.889999  11619900.0
# 178728  CMCSA  25.340000  25.510000  25.160000  25.620001  22672600.0
# mean: [4.18106867e+01 4.18286152e+01 4.14352100e+01 4.21812373e+01
#  1.48477256e+07]
# ----------
# symbol: CME shape: (1762, 6)
#        symbol       open      close        low       high     volume
# 279564    CME  52.096001  51.708000  51.458000  52.234001  2433500.0
# 66718     CME  57.153999  56.702000  56.700001  57.580002  2526500.0
# 288006    CME  54.928001  54.650002  54.566002  55.526001  2872000.0
# mean: [7.27149841e+01 7.27386288e+01 7.19962021e+01 7.34108593e+01
#  2.22916311e+06]
# ----------
# symbol: CMG shape: (1762, 6)
#        symbol        open       close        low        high    volume
# 433066    CMG  398.529999  400.079987  398.00000  403.940002  270900.0
# 347101    CMG  273.630005  274.049988  273.01001  277.739990  526100.0
# 280972    CMG  394.420013  392.130005  390.00000  399.899994  574100.0
# mean: [4.11112832e+02 4.11253990e+02 4.06546635e+02 4.15820948e+02
#  7.52493984e+05]
# ----------
# symbol: CMI shape: (1762, 6)
#        symbol        open       close         low        high     volume
# 392771    CMI  110.440002  106.389999  105.949997  110.629997  5944700.0
# 268779    CMI  112.570000  116.050003  112.160004  116.769997  2525600.0
# 785230    CMI  108.400002  109.730003  107.580002  109.980003  1748400.0
# mean: [1.12269642e+02 1.12285624e+02 1.11004972e+02 1.13523598e+02
#  2.19446572e+06]
# ----------
# symbol: CMS shape: (1762, 6)
#        symbol   open      close        low       high     volume
# 67657     CMS  16.01  15.920000  15.790000  16.059999  3611800.0
# 606667    CMS  37.50  37.459999  37.259998  37.540001  1270300.0
# 681733    CMS  32.32  32.099998  31.940001  32.480000  3714800.0
# mean: [2.74909081e+01 2.75065380e+01 2.72718502e+01 2.77053803e+01
#  2.71708348e+06]
# ----------
# symbol: CNC shape: (1762, 6)
#        symbol       open      close        low       high     volume
# 189989    CNC  13.569999  14.450000  13.430001  14.770001  2246400.0
# 487780    CNC  30.924999  30.770000  30.365000  31.065001  1251400.0
# 333503    CNC  19.254999  19.139999  18.995001  19.445000  1542400.0
# mean: [3.41240891e+01 3.41403661e+01 3.36411465e+01 3.46040437e+01
#  1.45452758e+06]
# ----------
# symbol: CNP shape: (1762, 6)
#        symbol   open  close        low       high     volume
# 114481    CNP  15.94  15.88  15.870000  16.049999  2400700.0
# 220944    CNP  19.52  19.25  19.049999  19.559999  6501000.0
# 439902    CNP  22.91  23.49  22.870001  23.490000  3329800.0
# mean: [2.02971623e+01 2.03020374e+01 2.01172928e+01 2.04696708e+01
#  3.96133178e+06]
# ----------
# symbol: COF shape: (1762, 6)
#        symbol       open      close        low       high     volume
# 21829     COF  38.990002  39.810001  38.750000  39.849998  4837100.0
# 453567    COF  70.589996  70.379997  70.070000  70.820000  3311200.0
# 449175    COF  71.620003  72.099998  71.080002  72.349998  3674400.0
# mean: [6.21848015e+01 6.22041430e+01 6.15661691e+01 6.27959024e+01
#  4.22513854e+06]
# ----------
# symbol: COG shape: (1762, 6)
#        symbol       open      close        low       high      volume
# 211566    COG  16.934999  17.227501  16.850001  17.844999  10656400.0
# 280978    COG  16.965000  17.135000  16.950001  17.530000   9793800.0
# 695129    COG  23.240000  23.240000  22.990000  23.530001   6789700.0
# mean: [2.31486464e+01 2.31469126e+01 2.27797517e+01 2.35042410e+01
#  6.62429654e+06]
# ----------
# symbol: COH shape: (1762, 6)
#        symbol       open      close        low       high      volume
# 722986    COH  32.959999  32.669998  32.610001  33.020000   1398400.0
# 745396    COH  38.619999  39.189999  38.430000  39.209999   3252300.0
# 731950    COH  33.349998  34.189999  33.270000  35.270000  11581000.0
# mean: [4.73287344e+01 4.73438820e+01 4.67594495e+01 4.79035244e+01
#  4.16822009e+06]
# ----------
# symbol: COL shape: (1762, 6)
#        symbol       open      close        low       high     volume
# 174048    COL  60.209999  60.520000  59.529999  60.830002  1080200.0
# 103231    COL  55.349998  55.160000  54.490002  55.750000  1499800.0
# 282856    COL  51.389999  50.619999  50.099998  51.389999  1041600.0
# mean: [7.04188082e+01 7.04559989e+01 6.98536379e+01 7.09909648e+01
#  9.82640409e+05]
# ----------
# symbol: COO shape: (1762, 6)
#        symbol        open       close         low        high    volume
# 93404     COO   50.389999   50.820000   50.340000   50.970001  210700.0
# 641184    COO  177.199997  177.820007  175.850006  178.850006  425400.0
# 262221    COO   77.900002   79.000000   77.629997   79.099998  348300.0
# mean: [1.12543791e+02 1.12596981e+02 1.11424614e+02 1.13655148e+02
#  4.77496254e+05]
# ----------
# symbol: COP shape: (1762, 6)
#        symbol       open      close        low       high      volume
# 167015    COP  55.100200  55.001098  54.452228  55.557590   8088600.0
# 823160    COP  41.580002  41.099998  40.820000  41.820000   5645300.0
# 238303    COP  55.466109  55.603328  55.252662  55.679557  10997700.0
# mean: [5.60535753e+01 5.60533724e+01 5.54880919e+01 5.65782246e+01
#  9.40266578e+06]
# ----------
# symbol: COST shape: (1762, 6)
#        symbol        open       close         low        high     volume
# 132779   COST   74.510002   74.959999   74.400002   75.099998  1435000.0
# 499035   COST  114.389999  115.209999  114.250000  115.620003  2173400.0
# 1754     COST   60.080002   59.709999   59.259998   60.439999  4527600.0
# mean: [1.09545851e+02 1.09596884e+02 1.08783905e+02 1.10329773e+02
#  2.45352951e+06]
# ----------
# symbol: COTY shape: (896, 6)
#        symbol   open      close        low       high     volume
# 705566   COTY  28.18  28.440001  27.510000  28.629999  1645500.0
# 650554   COTY  25.49  25.680000  25.290001  25.700001   877100.0
# 702584   COTY  29.00  28.950001  28.639999  29.180000  1258600.0
# mean: [2.16115179e+01 2.16171428e+01 2.13108036e+01 2.19039397e+01
#  2.24793237e+06]
# ----------
# symbol: CPB shape: (1762, 6)
#        symbol       open      close        low       high     volume
# 277701    CPB  33.720001  34.029999  33.720001  34.240002  2388400.0
# 425765    CPB  47.320000  47.480000  47.130001  47.799999   659600.0
# 761338    CPB  61.259998  59.830002  59.750000  61.279999  2386200.0
# mean: [4.23896765e+01 4.24200000e+01 4.20908796e+01 4.27053859e+01
#  1.94409120e+06]
# ----------
# symbol: CRM shape: (1762, 6)
#        symbol       open      close        low       high     volume
# 497082    CRM  63.750000  63.139999  62.730000  63.869999  3958800.0
# 521532    CRM  51.599998  51.799999  50.490002  51.930000  4646100.0
# 749387    CRM  72.529999  72.720001  71.599998  73.180000  3379700.0
# mean: [4.87568842e+01 4.87691374e+01 4.81050369e+01 4.93884819e+01
#  7.51062316e+06]
# ----------
# symbol: CSCO shape: (1762, 6)
#        symbol       open  close    low       high      volume
# 208291   CSCO  16.209999  16.75  16.17  16.760000  74775100.0
# 847616   CSCO  30.639999  30.68  30.60  30.820000  14175500.0
# 531802   CSCO  24.490000  24.50  24.41  24.620001  17972800.0
# mean: [2.32386549e+01 2.32464359e+01 2.30367707e+01 2.34473950e+01
#  4.19861297e+07]
# ----------
# symbol: CSRA shape: (284, 6)
#        symbol       open      close        low       high     volume
# 769309   CSRA  24.240000  24.270000  24.080000  24.490000   602700.0
# 821669   CSRA  26.120001  25.940001  25.930000  26.190001   688200.0
# 784747   CSRA  22.350000  22.350000  21.950001  22.559999  1550100.0
# mean: [2.69079225e+01 2.69120599e+01 2.65061585e+01 2.73071021e+01
#  1.47392958e+06]
# ----------
# symbol: CSX shape: (1762, 6)
#        symbol       open      close        low       high     volume
# 81710     CSX  18.480000  18.360001  18.293333  18.500000  5379900.0
# 732956    CSX  22.549999  23.020000  22.530001  23.030001  8511700.0
# 398581    CSX  25.850000  25.700001  25.580000  25.940001  5021000.0
# mean: [2.54335717e+01 2.54419372e+01 2.51740409e+01 2.56964226e+01
#  8.90492736e+06]
# ----------
# symbol: CTAS shape: (1762, 6)
#        symbol       open      close        low       high     volume
# 698116   CTAS  92.480003  92.669998  92.150002  92.970001   362000.0
# 227522   CTAS  30.750000  30.570000  30.430000  30.900000   764900.0
# 181091   CTAS  31.370001  31.059999  30.879999  31.370001  1093100.0
# mean: [5.63116855e+01 5.63325198e+01 5.58681102e+01 5.67396425e+01
#  8.06598865e+05]
# ----------
# symbol: CTL shape: (1762, 6)
#        symbol       open      close        low       high     volume
# 166084    CTL  43.270000  43.189999  43.000000  43.349998  5433000.0
# 266450    CTL  38.439999  38.580002  38.419998  38.740002  3938200.0
# 57844     CTL  33.680000  33.310001  33.279999  33.840000  3675400.0
# mean: [3.51268616e+01 3.51120432e+01 3.48034960e+01 3.54047674e+01
#  5.16382333e+06]
# ----------
# symbol: CTSH shape: (1762, 6)
#        symbol       open      close        low       high     volume
# 159988   CTSH  39.369999  38.375000  37.970001  39.375000  4200000.0
# 210640   CTSH  35.509999  35.509999  35.040001  35.665001  4900200.0
# 789238   CTSH  57.990002  58.360001  57.950001  58.680000  3313100.0
# mean: [4.35172474e+01 4.35289330e+01 4.30524489e+01 4.39629740e+01
#  5.09965148e+06]
# ----------
# symbol: CTXS shape: (1762, 6)
#        symbol       open      close        low       high     volume
# 191881   CTXS  59.980000  58.700001  57.299999  60.279999  4054600.0
# 359953   CTXS  67.750000  67.570000  67.160004  68.010002  1992300.0
# 679271   CTXS  69.260002  66.199997  66.150002  69.330002  2728700.0
# mean: [6.80764586e+01 6.80855789e+01 6.72023327e+01 6.89097560e+01
#  2.36645653e+06]
# ----------
# symbol: CVS shape: (1762, 6)
#        symbol       open       close        low        high     volume
# 724993    CVS  95.529999   95.559998  95.070000   96.459999  5901400.0
# 608165    CVS  99.449997  100.110001  99.209999  100.169998  4900800.0
# 554791    CVS  78.910004   79.239998  78.910004   79.599998  3502200.0
# mean: [6.36519580e+01 6.36719864e+01 6.31566288e+01 6.41550851e+01
#  6.93845227e+06]
# ----------
# symbol: CVX shape: (1762, 6)
#        symbol        open       close         low        high      volume
# 665385    CVX   94.279999   94.480003   93.900002   94.730003   6422700.0
# 166557    CVX  104.730003  102.489998  102.080002  104.949997   8196100.0
# 760352    CVX   99.000000  100.500000   98.160004  100.529999  10584800.0
# mean: [1.03327106e+02 1.03355057e+02 1.02462395e+02 1.04130636e+02
#  7.93193479e+06]
# ----------
# symbol: CXO shape: (1762, 6)
# ...
#  1.51681802e+07]
# ----------
# symbol: VAR shape: (1762, 6)
#        symbol       open      close        low       high     volume
# 188919    VAR  56.700001  52.660000  52.549999  57.509998  2057100.0
# 256924    VAR  65.190002  64.480003  64.300003  65.269997  1132000.0
# 752724    VAR  78.029999  77.940002  77.529999  78.129997   293200.0
# mean: [7.30423836e+01 7.30922248e+01 7.24344040e+01 7.36737401e+01
#  8.98812883e+05]
# ----------
# symbol: VFC shape: (1762, 6)
#        symbol       open      close        low       high     volume
# 626745    VFC  75.919998  75.389999  75.150002  75.989998  1328400.0
# 838484    VFC  57.009998  55.630001  55.490002  57.009998  3384200.0
# 211901    VFC  33.372501  32.689999  32.617500  33.447498  2109600.0
# mean: [4.66586876e+01 4.66729824e+01 4.62160783e+01 4.70836081e+01
#  2.90501067e+06]
# ----------
# symbol: VIAB shape: (1762, 6)
#        symbol       open      close        low       high     volume
# 680110   VIAB  39.700001  38.610001  38.160000  39.959999  7108600.0
# 363661   VIAB  59.509998  60.349998  59.029999  60.840000  5392300.0
# 799064   VIAB  43.799999  42.520000  42.419998  43.860001  2731200.0
# mean: [5.42674574e+01 5.42695233e+01 5.36615097e+01 5.48700681e+01
#  3.84878195e+06]
# ----------
# symbol: VLO shape: (1762, 6)
#        symbol       open      close        low       high     volume
# 510630    VLO  51.549999  52.049999  51.310001  52.279999  6014200.0
# 298199    VLO  21.709320  21.956119  21.672760  22.093240  8426500.0
# 271466    VLO  21.828149  21.846439  21.627059  22.166360  7542500.0
# mean: [3.92056316e+01 3.92162099e+01 3.86246310e+01 3.97673946e+01
#  8.89033422e+06]
# ----------
# symbol: VMC shape: (1762, 6)
#        symbol       open      close        low       high    volume
# 359325    VMC  54.500000  55.139999  54.340000  55.400002  879600.0
# 499873    VMC  67.349998  65.790001  65.610001  67.349998  652300.0
# 209090    VMC  29.410000  28.040001  27.530001  29.629999  988900.0
# mean: [6.31318105e+01 6.31532065e+01 6.23389047e+01 6.39152270e+01
#  1.11314478e+06]
# ----------
# symbol: VNO shape: (1762, 6)
#        symbol       open      close        low       high     volume
# 486182    VNO  82.291669  83.179350  81.902167  83.695646  1289800.0
# 99823     VNO  80.697455  80.652167  80.072469  81.050726  2798000.0
# 582026    VNO  98.559774  98.913038  98.532606  99.221021   941400.0
# mean: [8.44068432e+01 8.44295227e+01 8.36149830e+01 8.51450182e+01
#  1.15444614e+06]
# ----------
# symbol: VRSK shape: (1762, 6)
#        symbol       open      close        low       high    volume
# 445628   VRSK  64.860001  64.370003  64.279999  64.860001  731500.0
# 812541   VRSK  81.120003  81.489998  80.690002  81.760002  624700.0
# 49748    VRSK  30.280001  30.020000  29.910000  30.500000  896100.0
# mean: [5.50776674e+01 5.51200625e+01 5.46407208e+01 5.55434053e+01
#  8.14048070e+05]
# ----------
# symbol: VRSN shape: (1762, 6)
#        symbol       open      close        low       high    volume
# 397475   VRSN  48.919998  48.930000  48.669998  49.180000  703100.0
# 568336   VRSN  55.009998  54.310001  54.049999  55.110001  885900.0
# 440261   VRSN  49.910000  50.439999  49.799999  50.500000  724800.0
# mean: [5.10887061e+01 5.11321226e+01 5.06206867e+01 5.16173270e+01
#  2.03793127e+06]
# ----------
# symbol: VRTX shape: (1762, 6)
#        symbol        open       close         low        high     volume
# 160787   VRTX   56.150002   58.009998   55.680000   58.869999  2100000.0
# 671684   VRTX  134.880005  136.990005  134.679993  139.149994  2161100.0
# 552689   VRTX   90.870003   90.879997   89.550003   91.849998  1053300.0
# mean: [7.11448638e+01 7.11338876e+01 6.98481839e+01 7.23629001e+01
#  2.12096067e+06]
# ----------
# symbol: VTR shape: (1762, 6)
#        symbol       open      close        low       high     volume
# 671189    VTR  66.830002  67.089996  66.830002  67.720001  2210400.0
# 433431    VTR  61.599998  62.860001  61.270000  63.070000  1853400.0
# 81575     VTR  52.189999  52.150002  51.599998  52.290001   707100.0
# mean: [6.05569126e+01 6.05657264e+01 5.99858116e+01 6.10867878e+01
#  2.01386476e+06]
# ----------
# symbol: VZ shape: (1762, 6)
#        symbol       open      close        low       high      volume
# 541444     VZ  50.570000  50.709999  50.369999  50.820000  14235400.0
# 327284     VZ  47.009998  46.570000  46.540001  47.070000   8718900.0
# 80172      VZ  30.200001  30.219999  30.070000  30.469999  13420300.0
# mean: [4.34224831e+01 4.34282932e+01 4.31013855e+01 4.37140808e+01
#  1.64509211e+07]
# ----------
# symbol: WAT shape: (1762, 6)
#        symbol        open       close         low        high    volume
# 376710    WAT   94.779999   94.239998   93.760002   94.919998  301300.0
# 812047    WAT  153.380005  152.889999  151.880005  154.229996  491300.0
# 254121    WAT   87.680000   88.980003   87.209999   89.610001  498800.0
# mean: [1.00672775e+02 1.00719489e+02 9.97914017e+01 1.01573093e+02
#  6.42294268e+05]
# ----------
# symbol: WBA shape: (1762, 6)
#        symbol       open      close        low       high     volume
# 433434    WBA  48.490002  47.250000  47.250000  48.580002  4421600.0
# 389269    WBA  48.610001  48.709999  48.279999  48.810001  3805700.0
# 172985    WBA  44.430000  45.180000  44.360001  45.340000  6499100.0
# mean: [5.54972588e+01 5.55302724e+01 5.49672418e+01 5.60467651e+01
#  6.57095704e+06]
# ----------
# symbol: WDC shape: (1762, 6)
#        symbol       open      close        low       high      volume
# 132183    WDC  34.369999  34.660000  34.360001  35.200001   3660100.0
# 33383     WDC  41.200001  41.770000  41.110001  42.320000   4331900.0
# 22175     WDC  37.330002  38.860001  36.220001  38.939999  14507900.0
# mean: [5.66035698e+01 5.65974518e+01 5.57958059e+01 5.73809535e+01
#  3.87117724e+06]
# ----------
# symbol: WEC shape: (1762, 6)
#        symbol       open      close        low       high     volume
# 184243    WEC  30.850000  31.629999  30.770000  31.799999  1506100.0
# 804066    WEC  61.400002  61.599998  61.270000  61.869999  1128200.0
# 321191    WEC  36.849998  36.860001  36.799999  37.169998  1339900.0
# mean: [4.15725057e+01 4.15962826e+01 4.12550993e+01 4.18899376e+01
#  1.66780233e+06]
# ----------
# symbol: WFC shape: (1762, 6)
#        symbol       open      close        low       high      volume
# 787101    WFC  46.700001  46.209999  45.810001  46.759998  22213000.0
# 388306    WFC  36.849998  37.060001  36.750000  37.220001  20352400.0
# 733317    WFC  49.290001  50.230000  49.169998  50.250000  25358300.0
# mean: [4.04772361e+01 4.04877412e+01 4.01259648e+01 4.08272362e+01
#  2.56992390e+07]
# ----------
# symbol: WFM shape: (1762, 6)
#        symbol       open      close        low       high     volume
# 50694     WFM  18.790001  19.180000  18.660000  19.245001  3979200.0
# 92346     WFM  18.040001  18.379999  17.959999  18.575001  5432600.0
# 239587    WFM  36.229999  36.134999  35.965000  36.435001  2122400.0
# mean: [3.76143218e+01 3.76307520e+01 3.72073553e+01 3.80277923e+01
#  4.62033428e+06]
# ----------
# symbol: WHR shape: (1762, 6)
#        symbol        open       close         low        high     volume
# 346520    WHR   97.830002   98.010002   97.339996   98.519997  1200500.0
# 221297    WHR   54.299999   53.790001   53.369999   54.849998  1544300.0
# 609506    WHR  199.460007  201.119995  197.000000  202.229996  1282500.0
# mean: [1.22573439e+02 1.22600993e+02 1.21030539e+02 1.24108405e+02
#  1.30778002e+06]
# ----------
# symbol: WLTW shape: (251, 6)
#     symbol        open       close         low        high     volume
# 40    WLTW  116.489998  117.000000  115.419998  117.669998   884700.0
# 218   WLTW  120.959999  122.489998  120.040001  122.599998  1089100.0
# 23    WLTW  113.300003  111.160004  110.459999  113.300003  1200500.0
# mean: [1.21943227e+02 1.21982988e+02 1.20617211e+02 1.23044781e+02
#  7.85629084e+05]
# ----------
# symbol: WM shape: (1762, 6)
#        symbol       open      close        low       high     volume
# 584484     WM  49.029999  49.090000  48.980000  49.160000  1149000.0
# 617888     WM  54.619999  54.279999  54.029999  54.660000  1759300.0
# 564435     WM  47.669998  47.349998  47.290001  47.689999  1801300.0
# mean: [4.31392168e+01 4.31603746e+01 4.28631328e+01 4.34307322e+01
#  2.63948411e+06]
# ----------
# symbol: WMB shape: (1762, 6)
#        symbol       open      close        low       high     volume
# 346053    WMB  32.240002  31.559999  31.450001  32.410000  5708200.0
# 629228    WMB  50.189999  50.590000  50.029999  50.889999  5412300.0
# 72693     WMB  15.790384  15.847455  15.790384  16.043104  3605200.0
# mean: [3.23036548e+01 3.23130992e+01 3.18718506e+01 3.27347184e+01
#  8.49921884e+06]
# ----------
# symbol: WMT shape: (1762, 6)
#        symbol       open      close        low       high      volume
# 463703    WMT  78.870003  79.809998  78.750000  79.870003   4812100.0
# 408599    WMT  74.839996  74.870003  74.800003  75.269997   6351500.0
# 301499    WMT  71.459999  72.250000  71.309998  72.489998  11052000.0
# mean: [6.70081215e+01 6.70364984e+01 6.65974744e+01 6.74611352e+01
#  9.52179841e+06]
# ----------
# symbol: WRK shape: (385, 6)
#        symbol       open      close        low       high     volume
# 814552    WRK  47.779999  48.290001  47.459999  48.369999  1742400.0
# 721869    WRK  45.689999  45.509998  45.290001  46.110001   442100.0
# 700967    WRK  53.299999  53.259998  52.189999  53.355000  1164100.0
# mean: [4.68543116e+01 4.68407273e+01 4.61113715e+01 4.75747246e+01
#  1.81996468e+06]
# ----------
# symbol: WU shape: (1762, 6)
#        symbol       open      close        low       high      volume
# 326826     WU  18.510000  18.459999  18.370001  18.590000   3108300.0
# 778642     WU  19.709999  19.639999  19.570000  19.709999   2438800.0
# 371890     WU  13.850000  14.000000  13.800000  14.130000  10566200.0
# mean: [1.78863678e+01 1.78918275e+01 1.77178661e+01 1.80612770e+01
#  6.12273695e+06]
# ----------
# symbol: WY shape: (1762, 6)
#        symbol       open      close    low   high     volume
# 285555     WY  19.430000  19.110001  19.10  19.59  6209200.0
# 658813     WY  32.299999  31.860001  31.84  32.41  2614900.0
# 732827     WY  24.730000  24.420000  24.26  24.91  7185900.0
# mean: [2.82045971e+01 2.82039955e+01 2.79027979e+01 2.84914018e+01
#  4.60760993e+06]
# ----------
# symbol: WYN shape: (1762, 6)
#        symbol       open      close        low       high     volume
# 108743    WYN  30.010000  30.299999  29.980000  30.510000  2090200.0
# 404253    WYN  58.380001  58.070000  56.820000  58.380001  2390400.0
# 12845     WYN  21.940001  22.219999  21.360001  22.500000  4442800.0
# mean: [5.68468729e+01 5.68634620e+01 5.62930477e+01 5.74015438e+01
#  1.63906039e+06]
# ----------
# symbol: WYNN shape: (1762, 6)
#        symbol        open       close         low        high      volume
# 483267   WYNN  206.500000  205.259995  203.720001  206.899994   1758400.0
# 738307   WYNN   62.750000   69.139999   62.299999   69.279999  10716600.0
# 544392   WYNN  207.369995  206.250000  205.330002  207.970001    792200.0
# mean: [1.23249500e+02 1.23193201e+02 1.21331680e+02 1.25057457e+02
#  2.46496691e+06]
# ----------
# symbol: XEC shape: (1762, 6)
#        symbol        open       close         low        high     volume
# 343245    XEC   60.540001   60.250000   59.500000   60.619999   606900.0
# 12380     XEC   53.200001   54.340000   53.200001   54.980000  2201500.0
# 687078    XEC  106.230003  109.260002  105.570000  109.690002  1189000.0
# mean: [9.19377526e+01 9.19766686e+01 9.04450227e+01 9.33877809e+01
#  1.11311918e+06]
# ----------
# symbol: XEL shape: (1762, 6)
#        symbol       open      close    low       high     volume
# 553685    XEL  31.000000  31.360001  30.90  31.389999  1569200.0
# 198325    XEL  23.760000  24.049999  23.59  24.080000  2479200.0
# 145797    XEL  23.549999  23.410000  23.41  23.770000  2079700.0
# mean: [2.99190295e+01 2.99334733e+01 2.96991771e+01 3.01328831e+01
#  2.92125079e+06]
# ----------
# symbol: XL shape: (1762, 6)
#        symbol       open      close        low   high     volume
# 393631     XL  31.139999  30.889999  30.799999  31.34  2217400.0
# 401842     XL  31.410000  31.500000  31.260000  31.60  1712100.0
# 58661      XL  16.129999  16.059999  15.590000  16.25  6204800.0
# mean: [2.82319013e+01 2.82447389e+01 2.79927696e+01 2.84811578e+01
#  2.99691901e+06]
# ----------
# symbol: XLNX shape: (1762, 6)
#        symbol       open      close        low       high     volume
# 757235   XLNX  46.480000  46.299999  45.980000  46.750000  1764100.0
# 412012   XLNX  39.099998  39.180000  38.639999  39.299999  3217400.0
# 166904   XLNX  35.669998  34.669998  34.660000  35.689999  3956800.0
# mean: [3.90637514e+01 3.90940011e+01 3.86853689e+01 3.94653746e+01
#  3.99291652e+06]
# ----------
# symbol: XOM shape: (1762, 6)
#        symbol       open      close        low       high      volume
# 138765    XOM  85.839996  84.720001  84.690002  86.080002  18062700.0
# 70363     XOM  61.919998  61.970001  61.250000  62.500000  23097300.0
# 801587    XOM  88.419998  87.809998  87.639999  88.500000   6432600.0
# mean: [8.39647673e+01 8.40064813e+01 8.33488649e+01 8.45758172e+01
#  1.63195062e+07]
# ----------
# symbol: XRAY shape: (1762, 6)
#        symbol       open      close        low       high    volume
# 173003   XRAY  36.270000  36.520000  36.230000  36.630001  363200.0
# 808075   XRAY  61.639999  61.650002  61.119999  61.900002  994800.0
# 298226   XRAY  36.310001  36.580002  36.290001  36.669998  803300.0
# mean: [4.45344608e+01 4.45580874e+01 4.41414302e+01 4.49233882e+01
#  1.06632866e+06]
# ----------
# symbol: XRX shape: (1762, 6)
#        symbol   open  close    low   high      volume
# 755246    XRX  11.08  11.00  11.00  11.22   5486000.0
# 496966    XRX  11.04  10.92  10.90  11.11  12271700.0
# 619873    XRX  13.43  13.37  13.24  13.43   5892000.0
# mean: [9.99316686e+00 9.99256527e+00 9.87322361e+00 1.01071566e+01
#  1.11251422e+07]
# ----------
# symbol: XYL shape: (1008, 6)
#        symbol   open      close        low       high     volume
# 800592    XYL  48.00  48.540001  48.000000  48.810001   886300.0
# 459806    XYL  33.82  33.939999  33.630001  34.090000  1118800.0
# 385908    XYL  27.85  27.959999  27.590000  28.030001   754000.0
# mean: [3.64659921e+01 3.64774702e+01 3.61478968e+01 3.67807143e+01
#  1.18002728e+06]
# ----------
# symbol: YHOO shape: (1762, 6)
#        symbol       open      close        low       high      volume
# 646004   YHOO  44.380001  40.980000  39.119999  44.660000  45363900.0
# 372385   YHOO  20.809999  21.160000  20.690001  21.309999  15697300.0
# 107345   YHOO  16.100000  16.379999  15.950000  16.450001  14653000.0
# mean: [2.72979171e+01 2.72919920e+01 2.69756016e+01 2.76099773e+01
#  1.99690659e+07]
# ----------
# symbol: YUM shape: (1762, 6)
#        symbol       open      close        low       high     volume
# 166440    YUM  40.150971  39.769952  39.568658  40.244428  6887700.0
# 142052    YUM  36.606759  36.556436  36.326386  36.937455  5186100.0
# 252736    YUM  46.966214  47.375989  46.800863  47.440690  5902600.0
# mean: [4.82005833e+01 4.82233881e+01 4.77863503e+01 4.86329906e+01
#  5.16368383e+06]
# ----------
# symbol: ZBH shape: (1762, 6)
#        symbol        open       close         low        high     volume
# 77388     ZBH   47.340000   48.009998   47.119999   48.080002  1409600.0
# 538046    ZBH  105.050003  105.129997  104.199997  105.470001   470800.0
# 413967    ZBH   75.169998   75.000000   74.849998   75.849998  1223700.0
# mean: [8.28258173e+01 8.28738592e+01 8.21254142e+01 8.35569921e+01
#  1.50994574e+06]
# ----------
# symbol: ZION shape: (1762, 6)
#        symbol   open      close        low       high     volume
# 376252   ZION  25.24  25.629999  25.209999  25.700001  1669900.0
# 426630   ZION  29.27  29.049999  28.889999  29.400000  1896500.0
# 389293   ZION  23.51  23.440001  23.100000  23.540001  2003200.0
# mean: [2.50583542e+01 2.50694892e+01 2.47266231e+01 2.53843303e+01
#  3.22718734e+06]
# ----------
# symbol: ZTS shape: (987, 6)
#        symbol       open      close        low       high     volume
# 572278    ZTS  36.669998  35.570000  35.529999  36.669998  6676400.0
# 467143    ZTS  31.070000  31.209999  30.959999  31.340000  3196400.0
# 384947    ZTS  31.730000  31.959999  30.570000  32.070000  3963500.0
# mean: [4.01500912e+01 4.01424316e+01 3.97147720e+01 4.05308409e+01
#  4.02011530e+06]
# ----------

# %%
df_all = pd.read_csv(csv_path_all).sort_values('date')  # read all data of stock market
df_all = df_all.drop(columns=['date'])

groups = [] # Select those companies that has 1762 entries and symbol is started with 'Y'
for symbol, group in df_all.groupby('symbol'):          # iterate different companies. group is a DataFrame that is subset of df_all
    if len(group) == 1762 and symbol.startswith('Y'):
        groups.append(group)
df = pd.concat(groups)                                  # Concatenate those groups
df = df.reset_index(drop=True)                          # Reset the index to 0, 1, ..., 1761

print(df.shape)
print(df['symbol'].unique())                            # Companies
# Out:
# (3524, 6)
# ['YHOO' 'YUM']
